# %%
def myfunc(a,b):
    #returns 5% of the sum of a and b
    return sum((a,b)) * 0.05

# %%
myfunc(40,60)
# Out:
# 5.0

# %%
def myfunc(a,b,c=0,d=0):
    #returns 5% of the sum of a and b
    return sum((a,b,c,d)) * 0.05

# %%
myfunc(40,60,100,100)
# Out:
# 15.0

# %%
def myfunc(a,b,c=0,d=0):
    #returns 5% of the sum of a and b
    return sum((a,b,c,d)) * 0.05

# %%
myfunc(40,60,100,100,100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2280/1071070589.py in <module>
# ----> 1 myfunc(40,60,100,100,100)
#
# TypeError: myfunc() takes from 2 to 4 positional arguments but 5 were given

# %%
def myfunc(*args):
    return sum(args) * 0.05

# %%
myfunc(40,100,200,600,50,40)
# Out:
# 51.5

# %% [markdown]
# *args = what ever this perameter is, it will be treated as a tuple.

# %% [markdown]
# **kwargs = builds a dictionary of whatever peramters are set

# %%
def myfunc(**kwargs):
    print(kwargs)
    if "fruit" in kwargs:
        print("My fruit of choice is {}".format(kwargs["fruit"]))
    else:
        print("I did not find any fruit here")

# %%
myfunc(fruit="apple",veggie="lettuce")
# Out:
# {'fruit': 'apple', 'veggie': 'lettuce'}
# My fruit of choice is apple

# %%
def myfunc(*args,**kwargs):
     
    print("I would like {} {}".format(args[0],kwargs["food"]))

# %%
myfunc(10,20,30,fruit="orange",food="eggs",animal="dog")
# Out:
# I would like 10 eggs

# %%
def myfunc(*args,**kwargs):
    print(args)
    print(kwargs)
    print("I would like {} {}".format(args[0],kwargs["food"]))

# %%
myfunc(10,20,30,fruit="orange",food="eggs",animal="dog")
# Out:
# (10, 20, 30)
# {'fruit': 'orange', 'food': 'eggs', 'animal': 'dog'}
# I would like 10 eggs

# %%
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# /tmp/ipykernel_3040/3265135689.py in <module>
# ----> 1 myfunc(20)
#
# /tmp/ipykernel_3040/3570078084.py in myfunc(*args)
#       1 def myfunc(*args):
# ----> 2     for letter in myfunc():
#       3         if letter % 2 == 0:
#       4             return upper()
#       5         else:
#
# ... last 1 frames repeated, from the frame below ...
#
# /tmp/ipykernel_3040/3570078084.py in myfunc(*args)
#       1 def myfunc(*args):
# ----> 2     for letter in myfunc():
#       3         if letter % 2 == 0:
#       4             return upper()
#       5         else:
#
# RecursionError: maximum recursion depth exceeded
