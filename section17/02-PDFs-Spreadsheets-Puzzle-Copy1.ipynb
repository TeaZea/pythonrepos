# %% [markdown]
# ___
#
# <a href='https://www.udemy.com/user/joseportilla/'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Content Copyright by Pierian Data</em></center>

# %% [markdown]
# # PDFs and Spreadsheets Puzzle Exercise
#
# Let's test your skills, the files needed for this puzzle exercise
#
# You will need to work with two files for this exercise and solve the following tasks:
#
# * Task One: Use Python to extract the Google Drive link from the .csv file. (Hint: Its along the diagonal from top left to bottom right).
# * Task Two: Download the PDF from the Google Drive link (we already downloaded it for you just in case you can't download from Google Drive) and find the phone number that is in the document. Note: There are different ways of formatting a phone number!

# %% [markdown]
# ## Task One: Grab the Google Drive Link from .csv File

# %%
import csv
import shutil

# %%
data = open("/home/stefano/pythonrepos/section17/Exersice-Folder-Copy/find_the_link-Copy1.csv",encoding="utf-8")

# %%
csv_data = csv.reader(data)

# %%
find_the_link = list(csv_data)

# %%
find_the_link
# Out:
# [['h',
#   '53',
#   '24',
#   '46',
#   '4',
#   '11',
#   '3',
#   '35',
#   '17',
#   '52',
#   '9',
#   '60',
#   '26',
#   '60',
#   '72',
#   '39',
#   '11',
#   '80',
#   '86',
#   '66',
#   '59',
#   '9',
#   '41',
#   '33',
#   '11',
#   '42',
#   '69',
#   '74',
#   '91',
#   '61',
#   '5',
#   '69',
#   '17',
#   '17',
#   '78',
#   '6',
#   '51',
#   '54',
#   '54',
#   '94',
#   '47',
#   '37',
#   '0',
#   '16',
#   '71',
#   '6',
#   '83',
#   '7',
#   '6',
#   '38',
#   '61',
#   '18',
#   '68',
#   '15',
#   '2',
#   '81',
#   '49',
#   '5',
#   '17',
#   '21',
#   '36',
#   '63',
#   '38',
#   '24',
#   '3',
#   '99'],
#  ['85',
#   't',
#   '31',
#   '54',
#   '60',
#   '22',
#   '77',
#   '39',
#   '93',
#   '38',
#   '31',
#   '16',
#   '29',
#   '27',
#   '8',
#   '35',
#   '0',
#   '54',
#   '84',
#   '21',
#   '47',
#   '37',
#   '66',
#   '83',
#   '26',
#   '22',
#   '68',
#   '25',
#   '44',
#   '81',
#   '27',
#   '68',
#   '17',
#   '63',
#   '13',
# ...

# %%
link = ""

#data is the row, row number in the row
for row_num,data in enumerate(find_the_link):
    
    link += data[row_num]

# %%
link
# Out:
# 'https://drive.google.com/open?id=1G6SEgg018UB4_4xsAJJ5TdzrhmXipr4Q'

# %%
# THe correct result is shown below, if you can't download from Google Drive, 
# we added the PDF file to the Exercise_Files folder already

# %% [markdown]
# ## Task Two: Download the PDF from the Google Drive link and find the phone number that is in the document.

# %%
# You should get this phone number
# 505 503 4455

# %%
import PyPDF2

# %%
import re

# %%
f = open("/home/stefano/pythonrepos/section17/Exersice-Folder-Copy/Find_the_Phone_Number-Copy1.pdf","rb")

# %%
pdf = PyPDF2.PdfFileReader(f)

# %%
pdf

# %%
pdf_reader.numPages

# %%
phone_num = ""

for num in range(pdf_reader.numPages):
    
    #get a page in range
    page = pdf_reader.getPage(num)
    
    #RE
    #create the pattern
    phone_pattern = re.compile(r'(\d{3})-(\d{3})-(\d{4})')
    
    #create an object for the result
    results = re.search(phone_pattern,page)
    
    #append the numbers to list
    phone_num.append(result)

# %%
pattern = r'\d{3}'

# %%
all_text = ""

for n in range(pdf.numPages):
    
    page = pdf.getPage(n)
    page_text = page.extractText()
    
    all_text = all_text+" "+page_text

# %%
all_text

# %%
re.findall(pattern,all_text)

# %%
#LECTURE SOLUTION

# %%
import PyPDF2

# %%
f = open("/home/stefano/pythonrepos/section17/Exersice-Folder-Copy/Find_the_Phone_Number-Copy1.pdf","rb")

# %%
pdf = PyPDF2.PdfFileReader(f)

# %%
pdf.numPages
# Out:
# 17

# %%
import re

# %%
pattern = r"\d{3}"

# %%
all_text = ""

for n in range(pdf.numPages):
    
    page = pdf.getPage(n)
    page_text = page.extractText()
    
    all_text = all_text+" "+page_text

# %%
all_text
# Out:
# ' Busin ess Del ivera bles\n \n \n \nSta ffe n g a g e me n tto u ch ba se ye tca n Ij u stch i me i n o n th a to n e d raw a l i ne i n th e sa n d  \nth i sp ro p o sa l i sa w i n\n-\nw i n si tua ti o n wh i ch wi l l cau se a ste l l a rp a ra d ig msh i ft,a n d  \np ro d u ce a mu l ti\n-\nfo l d in cre a se i n d el i ve ra b le sb u t \nfu tu re\n-\np ro o f.Id o n tca re i fyo u g o tso me  \nco p y,w h yyo u d o n tu se o ffi cei p su mco mo rso me th i n g li ke th a t? l o w\n-\nha n gi n g fru i tb e e f \nu p ,a n d o p ti mi ze fo rse a rch o rw e ne e d to l e ve ra g e o u rsyn e rg i e s.We n e ed to ma ke th e  \nn e w ve rsio n cl e an a n d se xybe l l san d w h i st\nle s,so me e ti n g a ssa ssi n ,a n d e xe cu te . \nBa se l in e th e p ro ced u re an d sa mep a g e you rd ep a rtme n tp u sh b a ckye tstra te g i chi g h\n-\nl e ve l 30 ,0 0 0 ftvi e w p o we rPo in tl e ss,b u td e l i ve rab l e sn o rci rcl e b a ck.Pa d dl e o n bo th  \nsi d e sco n v
# ...

# %%
test = re.search(pattern,all_text)

# %%
test

# %%
for match in re.finditer(pattern,all_text):
    print(match)
